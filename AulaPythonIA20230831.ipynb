# %% [markdown]
# <a href="https://colab.research.google.com/github/AoruFernando01/AoruFernando01/blob/main/AulaPythonIA20230831.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Conexão com o drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Carrega a biblioteca pandas e atribui um alias chamado "pd"
import pandas as pd

# %%
# Deixar colunas e linhas aparentes
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Faz a leitura do arquivo train.csv
df = pd.read_csv('/content/drive/MyDrive/atividade/train.csv')

# %%
# Primeiras cinco linhas do dataset
df.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.tail(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1455         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1456         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 1458         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1459         Lvl    AllPub    Inside       Gtl      Edwards       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
# Cinco amostras aleatórias do dataset
df.sample(5)

# %%
# Informações do dataset como data type, quantidades, dados faltantes
df.info()

# %%
# Frequencia da coluna YrSold
# Aqui mostra todas as possibilidades que existem na coluna com o número
#   de vezes que aparece
df['YrSold'].value_counts(dropna=False)
# Out:
# 2009    338
# 2007    329
# 2006    314
# 2008    304
# 2010    175
# Name: YrSold, dtype: int64

# %%
# A opção normalize=True mostra a distribuição %
df.YrSold.value_counts(dropna=False, normalize=True)
# Out:
# 2009    0.231507
# 2007    0.225342
# 2006    0.215068
# 2008    0.208219
# 2010    0.119863
# Name: YrSold, dtype: float64

# %%
# Apenas mostra as colunas do seu dataframe em ordem alfabética
# Não está alterando o seu dataframe
sorted(df.columns)
# Out:
# ['1stFlrSF',
#  '2ndFlrSF',
#  '3SsnPorch',
#  'Alley',
#  'BedroomAbvGr',
#  'BldgType',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'BsmtQual',
#  'BsmtUnfSF',
#  'CentralAir',
#  'Condition1',
#  'Condition2',
#  'Electrical',
#  'EnclosedPorch',
#  'ExterCond',
#  'ExterQual',
#  'Exterior1st',
#  'Exterior2nd',
#  'Fence',
#  'FireplaceQu',
#  'Fireplaces',
#  'Foundation',
#  'FullBath',
#  'Functional',
#  'GarageArea',
#  'GarageCars',
#  'GarageCond',
#  'GarageFinish',
#  'GarageQual',
#  'GarageType',
#  'GarageYrBlt',
#  'GrLivArea',
#  'HalfBath',
#  'Heating',
#  'HeatingQC',
#  'HouseStyle',
#  'Id',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'LandContour',
#  'LandSlope',
#  'LotArea',
#  'LotConfig',
#  'LotFrontage',
#  'LotShape',
#  'LowQualFinSF',
#  'MSSubClass',
#  'MSZoning',
#  'MasVnrArea',
#  'MasVnrType',
#  'MiscFeature',
#  'MiscVal',
#  'MoSold',
# ...

# %%
# Mostra o número linhas, número de colunas
df.shape
# Out:
# (1460, 81)

# %%
# Mostra o número linhas, número de colunas
print('Shape do df original:', df.shape)
# Out:
# Shape do df original: (1460, 81)

# %%
# Mostra o total de linhas do df
len(df)
# Out:
# 1460

# %%
# Criando um dataset menor para facilitar
df_menor = df[[
 'Id',
 'GarageCars',
 'GarageFinish',
 'GarageType',
 'GarageYrBlt',
 'GrLivArea',
 'LotArea',
 'LotFrontage',
 'MSSubClass',
 'MSZoning',
 'MasVnrArea',
 'SaleCondition',
 'SalePrice',
 'SaleType',
 'YrSold'
]]
df_menor.shape
# Out:
# (1460, 15)

# %%
# Mostra o número de linhas do dataframe
len(df_menor)
# Out:
# 1460

# %%
# Mostra as 4 primeiras linhas do dataframe
df_menor.head(4)
# Out:
#    Id  GarageCars GarageFinish GarageType  GarageYrBlt  GrLivArea  LotArea  \
# 0   1           2          RFn     Attchd       2003.0       1710     8450
# 1   2           2          RFn     Attchd       1976.0       1262     9600
# 2   3           2          RFn     Attchd       2001.0       1786    11250
# 3   4           3          Unf     Detchd       1998.0       1717     9550
#
#    LotFrontage  MSSubClass MSZoning  MasVnrArea SaleCondition  SalePrice  \
# 0         65.0          60       RL       196.0        Normal     208500
# 1         80.0          20       RL         0.0        Normal     181500
# 2         68.0          60       RL       162.0        Normal     223500
# 3         60.0          70       RL         0.0       Abnorml     140000
#
#   SaleType  YrSold
# 0       WD    2008
# 1       WD    2007
# 2       WD    2008
# 3       WD    2006

# %%
# Estatísticas do dataset
df_menor.describe()

# %%
# Estatísticas de colunas categoricas, a inclusão de 'o' ou 'object'
# df_menor.describe(include='o')
df_menor.describe(include='object')

# %%
# Lista (array) com as possibilidades de categorias da coluna
df_menor.SaleCondition.unique()
# Out:
# array(['Normal', 'Abnorml', 'Partial', 'AdjLand', 'Alloca', 'Family'],
#       dtype=object)

# %%
# Lista (array) com as possibilidades de categorias da coluna
df_menor.YrSold.unique()
# Out:
# array([2008, 2007, 2006, 2009, 2010])

# %%
# Frequencia da coluna SaleCondition
df_menor.SaleCondition.value_counts(dropna=False)
# Out:
# Normal     1198
# Partial     125
# Abnorml     101
# Family       20
# Alloca       12
# AdjLand       4
# Name: SaleCondition, dtype: int64

# %%
# Mostra nome das colunas
df_menor.columns

# sorted(df_menor.columns)
# Out:
# Index(['Id', 'GarageCars', 'GarageFinish', 'GarageType', 'GarageYrBlt',
#        'GrLivArea', 'LotArea', 'LotFrontage', 'MSSubClass', 'MSZoning',
#        'MasVnrArea', 'SaleCondition', 'SalePrice', 'SaleType', 'YrSold'],
#       dtype='object')

# %%
# Altera nome da coluna Id
df_menor.rename({'Id': 'Identificação'}, axis=1, inplace=True)

# %%
# Checando o df
# Mostra o número de linhas e colunas do df
print(df_menor.shape)

# %%
# Contabiliza as possibilidades únicas de categorias da coluna
df_menor.YrSold.nunique()
# Out:
# 5

# %%
# Mostra o número de ID únicos
print(df_menor.Id.nunique())

# %%
# Altera nome da coluna Id
df_menor.rename({'Id': 'Identificação'}, axis=1, inplace=True)

# %%
# Selecionando apenas uma variável, YrSold
# df_menor['YrSold'].sample(4)
df_menor.YrSold.sample(4)

# %%
# Média da variável LotArea
df_menor['LotArea'].mean()

# %%
# Soma da variável LotArea
df_menor['LotArea'].sum()

# %%
# Cálculo da média pela fórmula
df_menor['LotArea'].sum()/len(df_menor)

# %%
# Desvio padrão da variável LotArea
df_menor['LotArea'].std()

# %%
# Contagem da variável LotArea
df_menor['LotArea'].count()

# %%
# Moda da variável LotArea
df_menor['LotArea'].mode()

# %%
# Filtrando dataset por MSZoning == RL - apenas visualização no output
# df_menor[['GarageCars','GarageFinish','GarageType','MSSubClass','MSZoning']].loc[df_menor['MSZoning'] == 'RL']

# Criando um novo df com a categoria MSZoning == RL
df_rl = df_menor[['GarageCars','GarageFinish','GarageType','MSSubClass','MSZoning']].loc[df_menor['MSZoning'] == 'RL']
print(df_rl.shape)
df_rl.head(4)

# %%
# Filtrando dataset por MSZoning == RL e GarageCars <=2 e GarageType == Attchd
# df_menor[['GarageCars','GarageFinish','GarageType','MSZoning']].loc[(df_menor['MSZoning']== 'RL') &
#                                                                                  (df_menor['GarageCars'] <=2) &
#                                                                                  (df_menor['GarageType'] == 'Attchd')].sample(10)
df_rl_2_att = df_menor[['GarageCars','GarageFinish','GarageType','MSZoning']].loc[(df_menor['MSZoning']== 'RL') &
                                                                                  (df_menor['GarageCars'] <=2) &
                                                                                  (df_menor['GarageType'] == 'Attchd')].sample(10)
df_rl_2_att.shape
# Out:
# (10, 4)

# %%
# Renomeando a coluna MSZoning para MSZ - transformando as categorias "string" em número de 0 a 4
df_menor['MSZ'] = df_menor['MSZoning'].map({'RL':0,
                                            'RM':1,
                                            'FV':2,
                                            'RH':3,
                                            'C (all)':4})
# Out:
# <ipython-input-24-4b94dad058bf>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_menor['MSZ'] = df_menor['MSZoning'].map({'RL':0,

# %%
# Frequencia da coluna GarageType
df_menor['GarageType'].value_counts(dropna=False)
# Out:
# Attchd     951
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64

# %%
# Preenchendo dados ausentes de GarageType com Attchd.
df_menor['GarageType'].fillna('Attchd', inplace=True)
# Out:
# <ipython-input-26-29f69aea9805>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_menor['GarageType'].fillna('Attchd', inplace=True)

# %%
# Checando novamente
df_menor.isna().sum()
# Out:
# Id                 0
# GarageCars         0
# GarageFinish      81
# GarageType         0
# GarageYrBlt       81
# GrLivArea          0
# LotArea            0
# LotFrontage      259
# MSSubClass         0
# MSZoning           0
# MasVnrArea         8
# SaleCondition      0
# SalePrice          0
# SaleType           0
# YrSold             0
# MSZ                0
# dtype: int64

# %%
# Frequencia da coluna GarageType
df_menor['GarageType'].value_counts(dropna=False)
# Out:
# Attchd     951
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64

# %%
# Agrupando dados pelo GarageType e calculando a média de todas as colunas do df
Media = df_menor.groupby('GarageType').mean()
Media
# Out:
# <ipython-input-30-77fd5632330f>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   Media = df_menor.groupby('GarageType').mean()
#                     Id  GarageCars  GarageYrBlt    GrLivArea       LotArea  \
# GarageType
# 2Types      705.833333    3.000000  1965.666667  1663.666667  17251.500000
# Attchd      729.777077    1.797056  1984.275862  1543.006309  11180.666667
# Basment     882.894737    1.578947  1962.473684  1567.894737  10433.789474
# BuiltIn     704.556818    2.250000  1996.829545  2103.284091  11996.306818
# CarPort     637.000000    1.666667  1960.111111  1357.000000  11674.333333
# Detchd      733.250646    1.576227  1962.782946  1312.930233   8421.860465
#
#             LotFrontage  MSSubClass  MasVnrArea      SalePrice       YrSold  \
# GarageType
# ...
